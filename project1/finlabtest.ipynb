# %%
from finlab import data

data.get('price:收盤價')
# Out:
# 請從 https://ai.finlab.tw/api_token 複製驗證碼，貼於此處:
#
# 輸入成功!
# 之後可以使用以下方法自動登入
# import finlab
# finlab.login("YOUR API TOKEN")
# Due to your status as a free user, the most recent data has been shortened or limited.
# Daily usage: 12.2 / 500 MB - price:收盤價
# symbol      0015    0050   0051    0052   0053   0054   0055   0056   0057  \
# date
# 2013-01-02  7.64   54.40  26.09   32.72  23.26  19.40  11.47  22.95  31.94
# 2013-01-03  7.64   54.85  26.12   32.12  23.11  19.37  11.49  23.06  31.93
# 2013-01-04  7.64   54.50  26.00   32.48  22.97  19.40  11.38  22.95  31.87
# 2013-01-07  7.64   54.25  25.84   32.09  22.81  19.21  11.39  22.97    NaN
# 2013-01-08  7.60   53.90  25.68   31.72  22.72  19.01  11.36  22.80  31.61
# ...          ...     ...    ...     ...    ...    ...    ...    ...    ...
# 2020-12-25   NaN  118.95  42.83  106.50  55.85  27.57  17.69  29.51  78.55
# 2020-12-28   NaN  120.00  43.83  107.80  56.85  27.90  17.71  29.75  79.10
# ...

# %%
data.get('benchmark_return:發行量加權股價報酬指數')
# Out:
# Daily usage: 11.2 / 500 MB - benchmark_return:發行量加權股價報酬指數
# symbol      發行量加權股價報酬指數
# date
# 2013-01-02     11164.55
# 2013-01-03     11247.23
# 2013-01-04     11202.96
# 2013-01-07     11129.91
# 2013-01-08     11081.93
# ...                 ...
# 2020-12-25     27667.00
# 2020-12-28     27959.77
# 2020-12-29     27938.50
# 2020-12-30     28354.81
# 2020-12-31     28441.36
#
# [1962 rows x 1 columns]

# %%
from finlab import data
import finlab
finlab.login("AiuPZ4WPXAATQGDkCCUjnGPeKpNfxa0pfe0iFPMxsNlgpZep3Qqp1KJjbwzikCtd#free")

df = data.get('financial_statement:現金及約當現金')
# Out:
# 輸入成功!
# Due to your status as a free user, the most recent data has been shortened or limited.
# Daily usage: 3.7 / 500 MB - financial_statement:現金及約當現金

# %%
df1 = data.get('financial_statement:本期綜合損益總額')
# Out:
# Daily usage: 4.9 / 500 MB - financial_statement:本期綜合損益總額

# %%
df_cleaned = df.dropna(axis=1)
df1_cleaned = df1.dropna(axis=1)

# %%
(df1_cleaned < 0).any().any()
# Out:
# True

# %%
data.get('intraday_trading:當日沖銷交易成交股數')
# Out:
# Daily usage: 18.2 / 500 MB - intraday_trading:當日沖銷交易成交股數
# symbol          0050    0051      0052  0053  0054     0055      0056  \
# date
# 2014-01-06       NaN     NaN       NaN   NaN   NaN      NaN       NaN
# 2014-01-07       NaN     NaN       NaN   NaN   NaN      NaN       NaN
# 2014-01-08       NaN     NaN       NaN   NaN   NaN      NaN       NaN
# 2014-01-09       NaN     NaN       NaN   NaN   NaN      NaN       NaN
# 2014-01-10       NaN     NaN       NaN   NaN   NaN      NaN       NaN
# ...              ...     ...       ...   ...   ...      ...       ...
# 2020-12-25  191000.0  1000.0  413000.0   0.0   0.0   3000.0  101000.0
# 2020-12-28  227000.0  5000.0  163000.0   0.0   0.0      0.0   73000.0
# 2020-12-29  135000.0  1000.0  335000.0   0.0   0.0   3000.0  190000.0
# 2020-12-30  402000.0     0.0  166000.0   0.0   0.0  22000.0   51000.0
# 2020-12-31  183000.0     0.0  247000.0   0.0   0.0  16000.0  187000.0
#
# ...

# %%
close = data.get('price:收盤價')

# %%
close.index
# Out:
# DatetimeIndex(['2013-01-02', '2013-01-03', '2013-01-04', '2013-01-07',
#                '2013-01-08', '2013-01-09', '2013-01-10', '2013-01-11',
#                '2013-01-14', '2013-01-15',
#                ...
#                '2020-12-18', '2020-12-21', '2020-12-22', '2020-12-23',
#                '2020-12-24', '2020-12-25', '2020-12-28', '2020-12-29',
#                '2020-12-30', '2020-12-31'],
#               dtype='datetime64[ns]', name='date', length=1962, freq=None)
